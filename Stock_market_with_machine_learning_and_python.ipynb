# %% [markdown]
# <a href="https://colab.research.google.com/github/Sam120204/Stock_Market_Analysis_and_Forecast_with_ML/blob/main/Stock_market_with_machine_learning_and_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

sp500 = yf.Ticker("AAPL")
sp500 = sp500.history(period="max")
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099319    0.099750    0.099319    0.099319
# 1980-12-15 00:00:00-05:00    0.094569    0.094569    0.094137    0.094137
# 1980-12-16 00:00:00-05:00    0.087659    0.087659    0.087228    0.087228
# 1980-12-17 00:00:00-05:00    0.089387    0.089818    0.089387    0.089387
# 1980-12-18 00:00:00-05:00    0.091978    0.092410    0.091978    0.091978
# ...                               ...         ...         ...         ...
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
# 2024-01-03 00:00:00-05:00  184.220001  185.880005  183.429993  184.250000
#
#                               Volume  Dividends  Stock Splits
# Date
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1980-12-12 00:00:00-05:00', '1980-12-15 00:00:00-05:00',
#                '1980-12-16 00:00:00-05:00', '1980-12-17 00:00:00-05:00',
#                '1980-12-18 00:00:00-05:00', '1980-12-19 00:00:00-05:00',
#                '1980-12-22 00:00:00-05:00', '1980-12-23 00:00:00-05:00',
#                '1980-12-24 00:00:00-05:00', '1980-12-26 00:00:00-05:00',
#                ...
#                '2023-12-19 00:00:00-05:00', '2023-12-20 00:00:00-05:00',
#                '2023-12-21 00:00:00-05:00', '2023-12-22 00:00:00-05:00',
#                '2023-12-26 00:00:00-05:00', '2023-12-27 00:00:00-05:00',
#                '2023-12-28 00:00:00-05:00', '2023-12-29 00:00:00-05:00',
#                '2024-01-02 00:00:00-05:00', '2024-01-03 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=10855, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
sp500["Tomorrow"] = sp500["Close"].shift(-1)
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099319    0.099750    0.099319    0.099319
# 1980-12-15 00:00:00-05:00    0.094569    0.094569    0.094137    0.094137
# 1980-12-16 00:00:00-05:00    0.087659    0.087659    0.087228    0.087228
# 1980-12-17 00:00:00-05:00    0.089387    0.089818    0.089387    0.089387
# 1980-12-18 00:00:00-05:00    0.091978    0.092410    0.091978    0.091978
# ...                               ...         ...         ...         ...
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
# 2024-01-03 00:00:00-05:00  184.220001  185.880005  183.429993  184.250000
#
#                               Volume    Tomorrow
# Date
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099319    0.099750    0.099319    0.099319
# 1980-12-15 00:00:00-05:00    0.094569    0.094569    0.094137    0.094137
# 1980-12-16 00:00:00-05:00    0.087659    0.087659    0.087228    0.087228
# 1980-12-17 00:00:00-05:00    0.089387    0.089818    0.089387    0.089387
# 1980-12-18 00:00:00-05:00    0.091978    0.092410    0.091978    0.091978
# ...                               ...         ...         ...         ...
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
# 2024-01-03 00:00:00-05:00  184.220001  185.880005  183.429993  184.250000
#
#                               Volume    Tomorrow  Target
# Date
# ...

# %%
sp500 = sp500.loc["1990-01-01":].copy()
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1990-01-02 00:00:00-05:00    0.249271    0.265181    0.247503    0.263414
# 1990-01-03 00:00:00-05:00    0.268718    0.268718    0.265181    0.265181
# 1990-01-04 00:00:00-05:00    0.270485    0.274021    0.263414    0.266066
# 1990-01-05 00:00:00-05:00    0.266950    0.270485    0.261646    0.266950
# 1990-01-08 00:00:00-05:00    0.265181    0.268718    0.261646    0.268718
# ...                               ...         ...         ...         ...
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
# 2024-01-03 00:00:00-05:00  184.220001  185.880005  183.429993  184.250000
#
#                               Volume    Tomorrow  Target
# Date
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

model = RandomForestClassifier(n_estimators = 100, min_samples_split = 100, random_state=1)

train = sp500.iloc[:-100] ##make the model to learn the data
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]

#train the model
model.fit(train[predictors], train["Target"])
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
#measure how accurate the model is
from sklearn.metrics import precision_score
preds = model.predict(test[predictors])

# %%
import pandas as pd
preds = pd.Series(preds, index=test.index)

# %%
precision_score(test["Target"], preds)
# Out:
# 0.6666666666666666

# %%
combined = pd.concat([test["Target"], preds], axis=1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#build backtesting system
def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict(test[predictors])
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
  all_predictions = []
  for i in range(start, data.shape[0], step):
    train = data.iloc[0:i].copy()
    test = data.iloc[i:(i+step)].copy()
    predictions = predict(train, test, predictors, model)
    all_predictions.append(predictions)
  return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# 0 is going down. 1 is going up (days)
# Out:
# 0    4128
# 1    1939
# Name: Predictions, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5157297576070139

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# 1    0.52151
# 0    0.47849
# Name: Target, dtype: float64

# %%
horizons = [2 ,5, 60, 250, 1000]
new_predictors = []
for horizon in horizons:
  rolling_averages = sp500.rolling(horizon).mean()

  ratio_column = f"Close_Ratio_{horizon}"
  sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

  trend_column = f"Trend_{horizon}"
  sp500[trend_column] = sp500.shift(1).rolling(horizon).sum()["Target"]

  new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna()
sp500
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1993-12-14 00:00:00-05:00    0.215842    0.219531    0.213997    0.214919
# 1993-12-15 00:00:00-05:00    0.213997    0.219531    0.213997    0.219531
# 1993-12-16 00:00:00-05:00    0.217686    0.219531    0.213997    0.216764
# 1993-12-17 00:00:00-05:00    0.217686    0.219531    0.214919    0.217686
# 1993-12-20 00:00:00-05:00    0.215842    0.219531    0.208462    0.210307
# ...                               ...         ...         ...         ...
# 2023-12-26 00:00:00-05:00  193.610001  193.889999  192.830002  193.050003
# 2023-12-27 00:00:00-05:00  192.490005  193.500000  191.089996  193.149994
# 2023-12-28 00:00:00-05:00  194.139999  194.660004  193.169998  193.580002
# 2023-12-29 00:00:00-05:00  193.899994  194.399994  191.729996  192.529999
# 2024-01-02 00:00:00-05:00  187.149994  188.440002  183.889999  185.639999
#
# ...

# %%
model = RandomForestClassifier(n_estimators=200, min_samples_split=50, random_state=1)

# %%
def predict(train, test, predictors, model):
  model.fit(train[predictors], train["Target"])
  preds = model.predict_proba(test[predictors])[:,1]
  preds[preds >= .6] = 1
  preds[preds < .6] = 0
  preds = pd.Series(preds, index=test.index, name="Predictions")
  combined = pd.concat([test["Target"], preds], axis=1)
  return combined

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()

# %%
precision_score(predictions["Target"], predictions["Predictions"])

# %%
#download the stock data
#clean and visiluize the data
#setup our machine learning target
#trained out initial model
#evaluate error and create a way to backtest and accurately measure the error over long period of time
#improve our model with extra predictor column
